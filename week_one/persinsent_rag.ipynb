# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'],
    keyword_fields=['course'],
    db_path='faq.db'
)

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
from rag_helper import RAGBase

assistant = RAGBase(sqlite_index, openai_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.'

# %%
assistant.rag('How do I can join?')
# Out:
# 'You don’t need to wait for a confirmation email — you’re already accepted. Just start learning and submit homework while the form is open. Registration is only to gauge interest.'

# %%
assistant.rag('Can i use docker?')
# Out:
# 'Yes — you can use Docker.'

# %%
assistant.rag('Should i know python to join?')
# Out:
# "I don't know."

# %%
assistant.rag('Can i use olama?')
# Out:
# 'Yes, you can use an open-source alternative to OpenAI API. The course notes mention that you can use any LLM platform for your experiments, and to refer to the `open-ai-alternatives.md` file in Module 1.\n\nIf you meant **Ollama** specifically, I don’t know from the provided context whether it’s explicitly supported, but it would fall under open-source alternatives.'

# %%
#sqlite_index.close()
